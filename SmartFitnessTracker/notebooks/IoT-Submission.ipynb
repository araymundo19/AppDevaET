# %%
import pandas as pd
from web3 import Web3
import time

ganache_url = "http://127.0.0.1:7545"
web3 = Web3(Web3.HTTPProvider(ganache_url))

if web3.is_connected():
    print("✅ Connected to Ganache successfully!")
else:
    print("❌ Connection failed. Ensure Ganache is running.")
# Out:
# ✅ Connected to Ganache successfully!

# %%
# Load IoT sensor data from CSV (Generated in Homework 1)
df = pd.read_csv("../data/fitness_mstracker_data.csv")

# Display the first few rows
print(df.head())
# Out:
#                     timestamp   user_id      activity_type  duration_minutes  \
# 0  2025-05-30 12:36:38.400715  USER8290  Strength Training                19
# 1  2025-05-30 13:07:38.400715  USER6338               Walk                22
# 2  2025-05-30 22:24:38.400715  USER8347               Yoga                64
# 3  2025-05-30 04:58:38.400715  USER6468               Walk                70
# 4  2025-05-30 23:16:38.401722  USER9082               Walk                82
#
#    steps  calories_burned  avg_heart_rate
# 0      0             99.9             125
# 1   5940            126.5             109
# 2      0            366.8              81
# 3   6465            682.2              87
# 4  11450            576.5             116

# %%
# Replace with your actual Remix contract address
contract_address = "0xc81c805F9079c041dA2F149A4073096f8164eD90"

# Replace with your actual ABI copied from Remix
abi = [
	{
		"anonymous": False,
		"inputs": [
			{
				"indexed": False,
				"internalType": "string",
				"name": "userId",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "timestamp",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "activityType",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "uint256",
				"name": "durationMinutes",
				"type": "uint256"
			},
			{
				"indexed": False,
				"internalType": "uint256",
				"name": "steps",
				"type": "uint256"
			},
			{
				"indexed": False,
				"internalType": "uint256",
				"name": "caloriesBurned",
				"type": "uint256"
			},
			{
				"indexed": False,
				"internalType": "uint256",
				"name": "avgHeartRate",
				"type": "uint256"
			}
		],
		"name": "DataStored",
		"type": "event"
	},
	{
		"inputs": [
			{
				"internalType": "string",
				"name": "_userId",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "_timestamp",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "_activityType",
				"type": "string"
			},
			{
				"internalType": "uint256",
				"name": "_durationMinutes",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "_steps",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "_caloriesBurned",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "_avgHeartRate",
				"type": "uint256"
			}
		],
		"name": "storeData",
		"outputs": [],
		"stateMutability": "nonpayable",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "uint256",
				"name": "index",
				"type": "uint256"
			}
		],
		"name": "getRecord",
		"outputs": [
			{
				"internalType": "string",
				"name": "",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "",
				"type": "string"
			},
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [],
		"name": "getTotalRecords",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"name": "records",
		"outputs": [
			{
				"internalType": "string",
				"name": "userId",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "timestamp",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "activityType",
				"type": "string"
			},
			{
				"internalType": "uint256",
				"name": "durationMinutes",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "steps",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "caloriesBurned",
				"type": "uint256"
			},
			{
				"internalType": "uint256",
				"name": "avgHeartRate",
				"type": "uint256"
			}
		],
		"stateMutability": "view",
		"type": "function"
	}
]  # Your contract ABI here (as a Python list)

# %%
contract = web3.eth.contract(address=contract_address, abi=abi)
web3.eth.default_account = web3.eth.accounts[0]
print(f"✅ Connected to Smart Contract at {contract_address}")
# Out:
# ✅ Connected to Smart Contract at 0xc81c805F9079c041dA2F149A4073096f8164eD90

# %%
# OLD DUMMY DATA TESTER
#txn = contract.functions.storeData("TEST001", "Temperature", "22.5°C").transact({
#    'from': web3.eth.default_account,
#    'gas': 1000000
#})
#
#web3.eth.wait_for_transaction_receipt(txn)
#print("✅ Dummy data stored on blockchain!")

# %%
# Define data upload function
def send_iot_data(row):
    txn = contract.functions.storeData(
        str(row["user_id"]),
        str(row["timestamp"]),
        str(row["activity_type"]),
        int(row["duration_minutes"]),
        int(row["steps"]),
        int(row["calories_burned"]),
        int(row["avg_heart_rate"])
    ).transact({
        'from': web3.eth.default_account,
        'gas': 3000000
    })

    receipt = web3.eth.wait_for_transaction_receipt(txn)
    print(f"✅ Data Stored: {row['activity_type']} for {row['user_id']} - Txn Hash: {receipt.transactionHash.hex()}")

# %%
# Auto Loop through the dataset and send all rows
for _, row in df.iterrows():
    send_iot_data(row)
# Out:
# ✅ Data Stored: Strength Training for USER8290 - Txn Hash: b4c636e6d96c991908225b53af93af5fbc3af387a65b6eb4d83f10374cef99bd
# ✅ Data Stored: Walk for USER6338 - Txn Hash: e118ba02d27d085e869d45c85323f87df419e9b18bcd580e604e6d01c4ccfb63
# ✅ Data Stored: Yoga for USER8347 - Txn Hash: 7586f486ed6175b484f974db7aaf15fc243a3aa5a10f479d632ceabf5744b0fd
# ✅ Data Stored: Walk for USER6468 - Txn Hash: ed8878b5c81c80cbf187e20fb02cbe031fe129ad72ddaa30f3e8e6328c855fb6
# ✅ Data Stored: Walk for USER9082 - Txn Hash: 475667be79e462f52260236d5398d9ddc726e344000f16936bda5084e0bbb55a
# ✅ Data Stored: Strength Training for USER9724 - Txn Hash: 360a6d0478110b3b85ab59b3b6a1dfa70cf01391c00a89225f89aeab95267eeb
# ✅ Data Stored: Swimming for USER1710 - Txn Hash: 04943fe6ac151c14fbe35110e6c357d616cbaeca706875326592537b1098b147
# ✅ Data Stored: Strength Training for USER5887 - Txn Hash: 2f8a3ad13d68fac3a639bdb995f3ece7599928b97f3ef3e322a3c711e7c72f1d
# ✅ Data Stored: Run for USER7883 - Txn Hash: 68bae23015af1f52ec60224198db5bcedf4a6c5e19b617a5172434fe033d9288
# ✅ Data Stored: Swimming for USER5786 - Txn Hash: 6a55829d576ab9ad1188a5843fe9dd244668767d03c8b4d3f798372a63208b85
# ✅ Data Stored: Walk for USER3561 - Txn Hash: aec642ae01e51cf60127fdb8bb47768cbef9aab628fe6dbe1e9b23544ade4c76
# ✅ Data Stored: Yoga for USER7681 - Txn Hash: 526b072aeaccc4cba35f109c3b4f1dd2a9f429fc4923be08fb6e8128bbe1d3b1
# ✅ Data Stored: Run for USER1911 - Txn Hash: c98f2aacce95736b0fc1986329746556e443abac12294bc437db2c940848add3
# ✅ Data Stored: Run for USER1009 - Txn Hash: d7ea92ccfe3bd7d258d331a49dea7bfb2093208e804325edcef96151758dc4d5
# ✅ Data Stored: Run for USER3013 - Txn Hash: 0e3ac46d359d592d918769e29c7cc9ca131b2fc57308408077114cc3947cc510
# ✅ Data Stored: Swimming for USER5979 - Txn Hash: 3d3635a8cd39476507db2599f9a17d31b7788eb981e142d4b5081d3c09af70ca
# ✅ Data Stored: Strength Training for USER5129 - Txn Hash: 126a638de1d6a28c4e6c3b63c0cd731b15f5616f136832f7bec371da0e58310d
# ✅ Data Stored: Swimming for USER4185 - Txn Hash: 24a4338004d3b9b27087402e39b485aedb18e564ee0b28b302c6c845f1e47e6b
# ✅ Data Stored: Yoga for USER6739 - Txn Hash: 8ef227200efaa624827c802d5bb00527ac28d382f06881e326f74a1414f01a2e
# ✅ Data Stored: Strength Training for USER8507 - Txn Hash: eddf4634f89c884554d4bb00511e6bb20c5f0b0659ec0fd695829675b1180935
# ✅ Data Stored: Strength Training for USER8663 - Txn Hash: 49ebf3b085198e19b2ac8fad201a552667a6c5bc178d8e86b561c54a5a6b30f2
# ✅ Data Stored: Strength Training for USER7438 - Txn Hash: 4777cd8a147c73b2dc3a170208e3e3b246a1866758758fb1c7f27d824f1016c4
# ✅ Data Stored: Run for USER2862 - Txn Hash: ca769d6cd354e4f6bf54d8200dd9904bf4fae89b7ded260e595ad9518dfb6a1e
# ✅ Data Stored: Walk for USER8307 - Txn Hash: e6ea0c42baf7166c20d27d5cf94a462281a366e86005d846788e563bd312e433
# ✅ Data Stored: Strength Training for USER5024 - Txn Hash: 5577790f5f8122ebea8fc885dd8e2c6756fc230136792a1a0b9b348fd263e211
# ✅ Data Stored: Run for USER4767 - Txn Hash: 1102df9e0ab61f256cb57e8603cb25c7874f7e7beb73ed15be3818821c247cac
# ✅ Data Stored: Cycling for USER2666 - Txn Hash: 6dcdd90c8a49f801f5b54a9191930cf5f501f147779b19bf04cf49447800a464
# ✅ Data Stored: Run for USER9977 - Txn Hash: 9f2d0991149e0010d805980fa43a66150834f385c1cbb3f776b274fba858b8f1
# ✅ Data Stored: Cycling for USER2631 - Txn Hash: e91c459a31b3aa6de617600a667351669fef9e238f5571b5b7ea02501b2d7d8e
# ✅ Data Stored: Yoga for USER9614 - Txn Hash: ebaacca5db2bdb9495ef6fa4de879a9a00152ae41278ac86d68fd51c30c4ad8e
# ✅ Data Stored: Run for USER2272 - Txn Hash: 996b941fe9e66f426ac66e55cadbc72c63f1f0f7afd3042bfa372630038982e3
# ✅ Data Stored: Yoga for USER8302 - Txn Hash: de48712bcfff70a59a81fd79ff221db8c4ce4235da452a232cb2934116b978ac
# ✅ Data Stored: Yoga for USER5835 - Txn Hash: 19818f2b152b892951264884d03bd70f13ec3d2da5d1821d85b9030d7593566b
# ✅ Data Stored: Yoga for USER9321 - Txn Hash: e45d6f8e4ab20f61214da1d3492ce0bb0b6be14e3ca5a615dc3d5d24744f9702
# ✅ Data Stored: Swimming for USER2340 - Txn Hash: 87765a7bcc2c60100a49b04a54fb01e7b2460d16d5f303f426f0a01017098da6
# ✅ Data Stored: Cycling for USER8639 - Txn Hash: 4a025700843657265fb0bab2741ed3955e72a544a8192d751c68180dbf6a6126
# ✅ Data Stored: Walk for USER2172 - Txn Hash: fbbc7a6c60840ecadc565944d16d1081401b254ca0a5125c12c96320a9cc9562
# ✅ Data Stored: Strength Training for USER2833 - Txn Hash: 69eb043421613ab90166d007080475a4ebead021244b7208ab707aa3a2748749
# ✅ Data Stored: Yoga for USER5704 - Txn Hash: 50be043355731c78b3c6263f7afc1847ea7fc679c6759c43eb469c754b429b9f
# ✅ Data Stored: Cycling for USER9779 - Txn Hash: 48c33285d6f2fed8c53e501bc018a349100bd840259219a81298b5b77ec58ff0
# ✅ Data Stored: Strength Training for USER3241 - Txn Hash: 1d17bb224b37b8af530363dd34d6367ab674951e5d89250af0a00b615049140b
# ✅ Data Stored: Yoga for USER5880 - Txn Hash: c97481db99a820ee723f70fb999e6a3e4dd683ab2a0e19899b1cf1319aad3acb
# ✅ Data Stored: Walk for USER7399 - Txn Hash: e592ec02b525c47fd8ffcb030b0a62cb979152ef773dac833f4cb8a74a6b095a
# ✅ Data Stored: Strength Training for USER7011 - Txn Hash: 8180bed91b99d265396c7bbfb461d8145766623082d371a113eab8bfe85e6e7c
# ✅ Data Stored: Cycling for USER8629 - Txn Hash: 8ce961731742735c2282880fcb0309d179415048e332fe13f4a05df41226e06d
# ✅ Data Stored: Run for USER8859 - Txn Hash: 3160b90ebe29062d58a0c85b74ea88642557f4ce947129eda99609f43a8b8c9b
# ✅ Data Stored: Run for USER1851 - Txn Hash: 7748302cb5f28b32b2c6fb1041784ee387fcedb8bdedbb17cf6830001513a4fa
# ✅ Data Stored: Walk for USER4462 - Txn Hash: 32c6d83f00b5e82119b9605891a440d77e5e835f3bd1b582079621ce5fe953ac
# ✅ Data Stored: Run for USER3107 - Txn Hash: 043ffd281b5ae92c1bf0df2072224f43fb3720cf3c71e8784ecffa4a1fd4ecab
# ✅ Data Stored: Cycling for USER6818 - Txn Hash: 8756bdf5b45a3b9be634c20fd5d7d3815b8cd884a39df0c1a8165d2fd5ca6330
# ✅ Data Stored: Cycling for USER4136 - Txn Hash: aa6fdf2ce19c56bfa1303fc2718de1f63b05465cf450172de8c7be0bd310b174
# ✅ Data Stored: Cycling for USER6623 - Txn Hash: 3c4208dd25a54ef19051ad3e0b8bbbd7e0ecf7bcecb8ab17804fcc1a794ba27a
# ✅ Data Stored: Cycling for USER5485 - Txn Hash: 7955eeebad6cd33e16ed60cd79d3b6f62b714017fd296184438d4656527b1caa
# ✅ Data Stored: Yoga for USER7695 - Txn Hash: 9c6615f34ef94e3ac6e34bd85a47a6b35f169733ef7ae6b642e5cb84c9594166
# ✅ Data Stored: Cycling for USER9471 - Txn Hash: a3f1f65bbee03f0314c6c23d5cb3a73aae4ccb050f2867739d095761422740ae
# ✅ Data Stored: Run for USER5111 - Txn Hash: 6b8ebb0b28d289cdf02b71169883b46fb76ab97897c18f08fe9087097e7dbfd5
# ✅ Data Stored: Walk for USER9050 - Txn Hash: 76a6a65d6847a9fcc5233790df75f2bf6c2009255f132e470b4d7d0b23acaec9
# ✅ Data Stored: Swimming for USER5153 - Txn Hash: e3f2acece8a5a493c8ae62cc7f86bf2e330742d2c98352606f23f231ad023879
# ✅ Data Stored: Swimming for USER6198 - Txn Hash: 3bb88b1b5454644c041430d77a4533824c00b0028ca62b063e60539854282798
# ✅ Data Stored: Walk for USER9091 - Txn Hash: 94734ac5ec128077eeaef99fa58707762b28b63eaab9286111edda6f0f4aa910
# ✅ Data Stored: Swimming for USER6576 - Txn Hash: d8527efab6b529bbe1336c4e6004eb645206ddb5d98d7d1acf03c9b221aae98a
# ✅ Data Stored: Swimming for USER4670 - Txn Hash: a067168195e12b19033580576606c5bbb5ff07bda42b50707b1653ff6d253716
# ✅ Data Stored: Walk for USER6821 - Txn Hash: 77465c04574b96c09818f74840305c0adaf9be9105ae240b229ae952dab04134
# ✅ Data Stored: Walk for USER8038 - Txn Hash: fb891ad3eb5df2a62d803b1038b7349b291baba6ed1914ac38c6f52f53f0b5ff
# ✅ Data Stored: Walk for USER1999 - Txn Hash: be1f417e72fff44cd0e88a1d9b0b8394e157c35e242301e1faca048aadbe0b9d
# ✅ Data Stored: Yoga for USER4019 - Txn Hash: f253d4749c984020099038b7f31d8aadc7eb958aa13052bb3730d6fb0ffe1fba
# ✅ Data Stored: Run for USER4070 - Txn Hash: 364b2962fdfd0407b7d2f0a35333ac8cbe8f4798b0a6c9c3219b67ca44de9a75
# ✅ Data Stored: Swimming for USER8085 - Txn Hash: e85318c651c1a3851a3650499c3ef06100151f5ca39cf04a1d43f67c58d97440
# ✅ Data Stored: Cycling for USER5812 - Txn Hash: 033927f70ccfc5e9098d510a5ab5043153b96db3f6b5e67f36ad908343a3f0e5
# ✅ Data Stored: Cycling for USER1275 - Txn Hash: 71a8ea5f4dfce5adef8f66873fc9aea95eec82ba7d97ee956c5b231d6173bcb9
# ✅ Data Stored: Walk for USER8445 - Txn Hash: 30a68a63b5f7e266cf21a50e8668bbe842f5ac9fc12fd3bc4bdfd77237a4e7b8
# ✅ Data Stored: Swimming for USER8392 - Txn Hash: 2d07715826633ff83c98d2041ceec34ff9c35af3affc5f66a5fb091ad98cba27
# ✅ Data Stored: Cycling for USER5684 - Txn Hash: ff19d26ec4f8c1e3b67c081d943b5d8332419164e545dde6e87fcd040ec6ae2f
# ✅ Data Stored: Strength Training for USER3612 - Txn Hash: 85237c073092a43ab63a991d55ce282739b3345bf7239c9ac14eb647edabaaba
# ✅ Data Stored: Swimming for USER9828 - Txn Hash: 73a6670852be70f4fd6db539c06fb4a1b37dbad8b716538442f078657df42615
# ✅ Data Stored: Strength Training for USER6104 - Txn Hash: aadb422344615e82d7f5eb2b858f2849a02555edfe8cb42dd7dee9e59ed4538e
# ✅ Data Stored: Walk for USER7243 - Txn Hash: 4312c533ef569d624a7b63ca57b49729e8a97a76a861497e976545b615b7159d
# ✅ Data Stored: Yoga for USER9449 - Txn Hash: 1ee3a318496b68344b67709e876aa1b7e5d1c5624fb8ea5466d9170e6f941672
# ✅ Data Stored: Walk for USER5421 - Txn Hash: 7a5c0bce05270b4abeec6338cc962e3a7f06e53d4a361b0b0af62a84aba27dac
# ✅ Data Stored: Run for USER5241 - Txn Hash: c7c608e4275c9522964f4662ee55b885dfd7a7360454c3f82307afa93ab1a3e9
# ✅ Data Stored: Walk for USER3970 - Txn Hash: c342d13756289190f678d3e38cf7786b00e25f2480867f219580a9723187cf7f
# ✅ Data Stored: Run for USER1561 - Txn Hash: 919fdc457af7714308b255b7e1d49bd2af708fa1a0c10db2a810c37fef8ec594
# ✅ Data Stored: Cycling for USER2657 - Txn Hash: 20e073e9d9378b3f58013b275db8bb4f66cfbc39b262ad29998a63438f7e52d9
# ✅ Data Stored: Cycling for USER9570 - Txn Hash: 4e858b6cb810e1eaa909e0d50f076f28bbda188edf28faaed76a9fb1a514b39e
# ✅ Data Stored: Run for USER6298 - Txn Hash: 4e33b29fbfaaa5168e483acc994a9a3dd8dc93a870d9e51ef9d7f21166e6e4b5
# ✅ Data Stored: Yoga for USER6137 - Txn Hash: a0bda9c5050afaa11b32452ed22cc46aafc9ad0321d261a1321958ef2d1396a9
# ✅ Data Stored: Swimming for USER1876 - Txn Hash: 982a1d66925e6821e25f085c4921991ebb23e03fa3a1b1d5c4d886baf4c0af5d
# ✅ Data Stored: Strength Training for USER1760 - Txn Hash: 1bb05b7cf50e6c4f71fc2304808d759d10fd4f929091c983399cca6ebe2d5e62
# ✅ Data Stored: Cycling for USER2249 - Txn Hash: ccf6b7072c21db298f760f60136e16d93a6b3a6af1713597e46d9cc3e8543cff
# ✅ Data Stored: Strength Training for USER7758 - Txn Hash: 51d73ae975a861d698005e3978a0e659f04f589ce1197a38d93c612ca6aa31f6
# ✅ Data Stored: Strength Training for USER9711 - Txn Hash: 749da611cbdb3b486534f83ec48cc2eb657d715e26d06b8bb7e5e76e4fe24092
# ✅ Data Stored: Strength Training for USER8673 - Txn Hash: 2f820fb1dee42cb834dcd1228b8c84a558d446f65cdf6b6a737a5878b619c7a5
# ✅ Data Stored: Yoga for USER7855 - Txn Hash: e55e506b7403aee993284f6f5e9f3737916cb764496d66f02cea16556d0daadc
# ✅ Data Stored: Walk for USER4306 - Txn Hash: c0e4c840b024e24d9752d2207f28b5859a95b36ac6ca843a59c3cb8b613b768a
# ✅ Data Stored: Yoga for USER2578 - Txn Hash: c3c8a6af96f6af9840e6439ed119bfdcf7e6802bf9cbc4740445956e5acf36aa
# ✅ Data Stored: Yoga for USER6733 - Txn Hash: e011bed3f5f6b5889a22458bcd943b2be7f54dae528a21d6f85a87dca29e4662
# ✅ Data Stored: Swimming for USER9760 - Txn Hash: 5c6ba970c34d904ba9b07139ae57ead2b2494288a24822bf96c2cc981fc587fe
# ✅ Data Stored: Strength Training for USER3077 - Txn Hash: c648b370b9449ba405a1a296d6441d6f2bedff3140affa2e81e5c29107f0ce32
# ✅ Data Stored: Walk for USER9550 - Txn Hash: 03183e076531f7814c61bb663f8451b61e201015e5afd1061b9c361500ef631c
# ✅ Data Stored: Swimming for USER6383 - Txn Hash: 068645eb9356c7e93699027c3d3e20a8f1f7cb8ae3d68abe14f903ad1a9f049e

# %%
# Old - Updated to get combine with total records
#record = contract.functions.getRecord(0).call()
#print("First Stored Record:", record)

# %%
# Confirm upload
total_records = contract.functions.getTotalRecords().call()
print(f"📦 Total records on blockchain: {total_records}")

# Display first record
first = contract.functions.getRecord(0).call()
print("🔍 First Stored Record:", first)
# Out:
# 📦 Total records on blockchain: 100
# 🔍 First Stored Record: ['USER8290', '2025-05-30 12:36:38.400715', 'Strength Training', 19, 0, 99, 125]
